# %% [markdown]
# #### Prepared for Gabor's Data Analysis
#
# ### Data Analysis for Business, Economics, and Policy
# by Gabor Bekes and  Gabor Kezdi
#
# Cambridge University Press 2021
#
# **[gabors-data-analysis.com ](https://gabors-data-analysis.com/)**
#
#  License: Free to share, modify and use for educational purposes.
#  Not to be used for commercial purposes.
#
# ### Chapter 01
# **CH01A Finding a Good Deal among Hotels: Data Collection**
#
# hotels-vienna dataset
#
# version 1.0 2021-05-05

# %% [markdown]
# ### Chapter 01
# #### First look at the hotels data

# %%
import os
import sys
import warnings

import numpy as np
import pandas as pd

warnings.filterwarnings("ignore")

# %%
# Current script folder
current_path = os.getcwd()
dirname = current_path.split("da_case_studies")[0]

# location folders
data_in = dirname + "da_data_repo/hotels-vienna/clean/"
data_out = dirname + "da_case_studies/ch01-hotels-data-collect/"
output = dirname + "da_case_studies/ch01-hotels-data-collect/output/"
func = dirname + "da_case_studies/ch00-tech-prep/"
sys.path.append(func)

# %%
# Import the prewritten helper functions 
from py_helper_functions import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Import the prewritten helper functions
# ----> 2 from py_helper_functions import *
#
# ModuleNotFoundError: No module named 'py_helper_functions'

# %%
# load in clean and tidy data and create workfile
df = pd.read_csv("data/hotels-vienna.csv")

# Download directly if you did not set up the folders
#df = pd.read_csv("https://osf.io/y6jvb/download")

# %%
rows, cols = df.shape
print("Rows:", rows)
print("Columns:", cols)
# Out:
# Rows: 428
# Columns: 24

# %%
df
# Out:
#      country city_actual  rating_count center1label center2label  \
# 0    Austria      Vienna          36.0  City centre    Donauturm
# 1    Austria      Vienna         189.0  City centre    Donauturm
# 2    Austria      Vienna          53.0  City centre    Donauturm
# 3    Austria      Vienna          55.0  City centre    Donauturm
# 4    Austria      Vienna          33.0  City centre    Donauturm
# ..       ...         ...           ...          ...          ...
# 423  Austria      Vienna           2.0  City centre    Donauturm
# 424  Austria      Vienna         145.0  City centre    Donauturm
# 425  Austria      Vienna         112.0  City centre    Donauturm
# 426  Austria      Vienna         169.0  City centre    Donauturm
# 427  Austria      Vienna          80.0  City centre    Donauturm
#
#     neighbourhood  price    city  stars  ratingta  ...      offer_cat  year  \
# 0     17. Hernals     81  Vienna    4.0       4.5  ...   15-50% offer  2017
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=428, step=1)

# %%
df_sample_twohundred = df.sample(n=200, random_state=42)

# %%
for i in range (3):
    df_sample_twenty = df.sample(n=20)
    average_price_twenty=df_sample_twenty['price'].mean()
    print(average_price_twenty)
# Out:
# 127.35
# 117.4
# 126.95

# %%
for i in range (3):
    df_sample_fifty = df.sample(n=50)
    average_price_fifty=df_sample_fifty['price'].mean()
    print(average_price_fifty)
# Out:
# 136.98
# 121.66
# 132.0

# %%
for i in range (3):
    df_sample_twohundred = df.sample(n=50)
    average_price_twohundred=df_sample_twohundred['price'].mean()
    print(average_price_twohundred)
# Out:
# 123.0
# 128.78
# 140.02

# %%
average_price=df['price'].mean()
print(average_price)
# Out:
# 131.36682242990653

# %%
############################################
# First look
############################################
df = df.filter(
    [
        "hotel_id",
        "accommodation_type",
        "country",
        "city",
        "city_actual",
        "neighbourhood",
        "center1label",
        "distance",
        "center2label",
        "distance_alter",
        "stars",
        "rating",
        "rating_count",
        "ratingta",
        "ratingta_count",
        "year",
        "month",
        "weekend",
        "holiday",
        "nnights",
        "price",
        "scarce_room",
        "offer",
        "offer_cat",
    ]
)

# %%
df.describe()
# Out:
#            hotel_id    distance  distance_alter       stars      rating  \
# count    428.000000  428.000000      428.000000  428.000000  393.000000
# mean   22153.502336    1.658879        3.718458    3.434579    3.970992
# std      146.858477    1.595673        1.631341    0.772278    0.577444
# min    21894.000000    0.000000        0.600000    1.000000    1.000000
# 25%    22027.750000    0.700000        2.700000    3.000000    3.700000
# 50%    22155.500000    1.300000        3.400000    3.500000    4.000000
# 75%    22279.250000    2.000000        4.400000    4.000000    4.400000
# max    22409.000000   13.000000       13.000000    5.000000    5.000000
#
#        rating_count    ratingta  ratingta_count    year  month  weekend  \
# count    393.000000  325.000000      325.000000   428.0  428.0    428.0
# mean     155.048346    3.990769      556.516923  2017.0   11.0      0.0
# std      191.217435    0.482638      586.874582     0.0    0.0      0.0
# ...

# %%
df = df.filter(
    [
        "hotel_id",
        "accommodation_type",
        "country",
        "city",
        "city_actual",
        "center1label",
        "distance",
        "stars",
        "rating",
        "price",
    ]
)

# %% [markdown]
# ### Table 1.1

# %%
df.head()
# Out:
#    hotel_id accommodation_type  country    city city_actual center1label  \
# 0     21894          Apartment  Austria  Vienna      Vienna  City centre
# 1     21897              Hotel  Austria  Vienna      Vienna  City centre
# 2     21901              Hotel  Austria  Vienna      Vienna  City centre
# 3     21902              Hotel  Austria  Vienna      Vienna  City centre
# 4     21903              Hotel  Austria  Vienna      Vienna  City centre
#
#    distance  stars  rating  price
# 0       2.7    4.0     4.4     81
# 1       1.7    4.0     3.9     81
# 2       1.4    4.0     3.7     85
# 3       1.7    3.0     4.0     83
# 4       1.2    4.0     3.9     82

# %%
import os

os.makedirs(output, exist_ok=True)  # creates all intermediate directories if needed
df.loc[0:4].to_csv(output + "hotel_listobs.csv", index=False)

# %%
print(len(df))

rows, cols = df.shape
print("Rows:", rows)
print("Columns:", cols)
# Out:
# 428
# Rows: 428
# Columns: 10
