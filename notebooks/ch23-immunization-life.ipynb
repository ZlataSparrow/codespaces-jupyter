# %% [markdown]
# #### Prepared for Gabor's Data Analysis
#
# ### Data Analysis for Business, Economics, and Policy
# by Gabor Bekes and  Gabor Kezdi
#
# Cambridge University Press 2021
#
# **[gabors-data-analysis.com ](https://gabors-data-analysis.com/)**
#
#  License: Free to share, modify and use for educational purposes.
#  Not to be used for commercial purposes.
#
# ### Chapter 16
# **CH16A Predicting apartment prices with random forest**
#
# using the airbnb dataset
#
# version 1.0 2021-05-05

# %%
import os
import sys
import warnings
from datetime import datetime as dt

import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
from IPython.core.display import HTML
from plotnine import *
from stargazer.stargazer import Stargazer

import seaborn as sns
import numpy as np

import matplotlib.pyplot as plt


warnings.filterwarnings("ignore")

# %%
# Current script folder
current_path = os.getcwd()
dirname = current_path.split("da_case_studies")[0]

# location folders
data_in = dirname + "da_data_repo/worldbank-immunization/clean/"
data_out = dirname + "da_case_studies/ch23-immunization-life/"
output = dirname + "da_case_studies/ch23-immunization-life/output/"

func = dirname + "da_case_studies/ch00-tech-prep/"
sys.path.append(func)

# %%
data = pd.read_csv("/workspaces/codespaces-jupyter/data/worldbank-immunization-continents.csv")

# %%
# Define color palette
color = sns.color_palette("Set1", n_colors=10)

# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the main lines for South Asia and sub-Saharan Africa
ax.plot(data['year'], data['imm_SAS'], color=color[0], linewidth=2, label='South Asia')
ax.plot(data['year'], data['imm_SSF'], color=color[1], linewidth=2, label='sub-Saharan Africa')

# Add the grey lines for other regions
for col in data.columns[1:6]:
    ax.plot(data['year'], data[col], color='grey', linewidth=0.7)

# Add annotations
ax.annotate('South Asia', xy=(data.loc[12, 'year'] - 2, data.loc[12, 'imm_SAS']), 
            fontsize=10, color='black')
ax.annotate('sub-Saharan Africa', xy=(data.loc[16, 'year'], data.loc[16, 'imm_SSF'] - 2), 
            fontsize=10, color='black')

# Set labels and limits
ax.set_xlabel('Date (year)')
ax.set_ylabel('Immunization rate (percent)')
ax.set_ylim(50, 100)
ax.set_yticks(np.arange(50, 101, 10))
ax.set_xlim(1998, 2018)
ax.set_xticks(range(1998, 2019, 5))

# Add grid for better readability
ax.grid(True, linestyle='--', alpha=0.7)

# Customize the appearance
sns.despine(left=False, bottom=False)
plt.tight_layout()

# Show plot
plt.show()

# %%
for col in data.columns[8:]:
    data[col] = data[col] / 10

# %%
# Define color palette (using the existing seaborn palette)
# Create figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the main lines for South Asia and sub-Saharan Africa
ax.plot(data['year'], data['surv_SAS'], color=color[0], linewidth=2, label='South Asia')
ax.plot(data['year'], data['surv_SSF'], color=color[1], linewidth=2, label='sub-Saharan Africa')

# Add the grey lines for other regions
for col in data.columns[8:13]:
    if col not in ['surv_SAS', 'surv_SSF']:
        ax.plot(data['year'], data[col], color='grey', linewidth=0.7)

# Add annotations
ax.annotate('South Asia', xy=(data.loc[12, 'year'] - 2, data.loc[12, 'surv_SAS']), 
            fontsize=10, color='black')
ax.annotate('sub-Saharan Africa', xy=(data.loc[16, 'year'] - 1, data.loc[16, 'surv_SSF'] - 2), 
            fontsize=10, color='black')

# Set labels and limits
ax.set_xlabel('Date (year)')
ax.set_ylabel('Child survival rate (percent)')
ax.set_ylim(80, 100)
ax.set_yticks(range(80, 101, 5))
ax.set_xlim(1998, 2018)
ax.set_xticks(range(1998, 2019, 5))

# Add grid for better readability
ax.grid(True, linestyle='--', alpha=0.7)

# Customize the appearance
sns.despine(left=False, bottom=False)
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# # Regressions on countries

# %%
data_panel = pd.read_csv("/workspaces/codespaces-jupyter/data/worldbank-immunization-panel.csv")
data_panel.describe()
# Out:
#               year          pop         mort         surv          imm  \
# count  3807.000000  3807.000000  3807.000000  3807.000000  3807.000000
# mean   2007.526924    35.067473    42.982847    95.701715    85.298135
# std       5.759522   132.455594    45.517445     4.551744    15.738758
# min    1998.000000     0.009332     2.100000    75.720000     8.000000
# 25%    2003.000000     1.756771     9.300000    93.425000    79.000000
# 50%    2008.000000     7.395599    23.300000    97.670000    92.000000
# 75%    2013.000000    23.576856    65.750000    99.070000    96.000000
# max    2017.000000  1386.395000   242.800000    99.790000    99.000000
#
#                gdppc      lngdppc         hexp
# count    3642.000000  3642.000000  3165.000000
# mean    16337.051802     9.042446     6.274914
# std     19070.325200     1.234401     2.878283
# min       275.518093     5.618653     1.024978
# 25%      3114.288251     8.043756     4.321824
# 50%      9386.069679     9.146982     5.766445
# 75%     22449.101714    10.019005     7.916312
# max    124024.568165    11.728235    27.417822

# %%
data_panel = data_panel.dropna(subset=["imm", "gdppc"])

# %%
data_panel
# Out:
#       year    c  countryname countrycode          pop  mort   surv  imm  \
# 0     1998  ARG    Argentina         ARG    36.063459  21.5  97.85   95
# 1     1998  AUS    Australia         AUS    18.711000   6.4  99.36   82
# 2     1998  BRA       Brazil         BRA   169.785250  39.5  96.05   95
# 3     1998  CHN        China         CHN  1241.935000  41.4  95.86   83
# 4     1998  FRA       France         FRA    60.186288   5.6  99.44   82
# ...    ...  ...          ...         ...          ...   ...    ...  ...
# 3801  2017  VUT      Vanuatu         VUT     0.285510  26.9  97.31   80
# 3803  2017  VNM      Vietnam         VNM    94.596642  20.9  97.91   97
# 3804  2017  YEM  Yemen, Rep.         YEM    27.834821  55.4  94.46   65
# 3805  2017  ZMB       Zambia         ZMB    16.853688  60.0  94.00   96
# 3806  2017  ZWE     Zimbabwe         ZWE    14.236745  50.3  94.97   90
#
#              gdppc    lngdppc  hexp
# 0     15973.067259   9.678659   NaN
# 1     33174.499840  10.409537   NaN
# 2     11193.381175   9.323078   NaN
# 3      3211.623211   8.074532   NaN
# 4     32679.688245  10.394509   NaN
# ...            ...        ...   ...
# 3801   2827.080453   7.947000   NaN
# 3803   6233.485045   8.737691   NaN
# 3804   2404.422370   7.785065   NaN
# 3805   3717.667166   8.220852   NaN
# 3806   2568.410072   7.851042   NaN
#
# [3642 rows x 11 columns]

# %%
data_panel["balanced"] = data_panel["c"].isin(
    data_panel.groupby("c")
    .agg(
        min_year=("year", min), max_year=("year", max), n_unique_years=("year", "count")
    )
    .query("(min_year == 1998)&(max_year == 2017)&(n_unique_years==20)")
    .index
)

# %%
data_balanced = data_panel.query("balanced == True")

# %%
countries_grouped = data_balanced.groupby("c")

data_balanced["lnpop"] = countries_grouped["pop"].transform(np.log)
data_balanced["d_surv"] = countries_grouped["surv"].transform("diff")
data_balanced["d_imm"] = countries_grouped["imm"].transform("diff")
data_balanced["d2_imm"] = countries_grouped["d_imm"].transform("diff")
data_balanced["d_lngdppc"] = countries_grouped["lngdppc"].transform("diff")
data_balanced["d_lnpop"] = countries_grouped["lnpop"].transform("diff")
data_balanced["avgpop"] = countries_grouped["pop"].transform("mean")

data_balanced = data_balanced.sort_values(by=["c", "year"])

# %%
data_balanced
# Out:
#       year    c countryname countrycode        pop   mort   surv  imm  \
# 24    1998  AGO      Angola         AGO  15.359601  215.6  78.44   60
# 211   1999  AGO      Angola         AGO  15.866869  211.4  78.86   42
# 400   2000  AGO      Angola         AGO  16.395473  206.3  79.37   35
# 589   2001  AGO      Angola         AGO  16.945753  200.3  79.97   64
# 778   2002  AGO      Angola         AGO  17.519417  193.4  80.66   64
# ...    ...  ...         ...         ...        ...    ...    ...  ...
# 3042  2013  ZWE    Zimbabwe         ZWE  13.350356   66.8  93.32   93
# 3233  2014  ZWE    Zimbabwe         ZWE  13.586681   61.1  93.89   92
# 3424  2015  ZWE    Zimbabwe         ZWE  13.814629   57.0  94.30   86
# 3615  2016  ZWE    Zimbabwe         ZWE  14.030390   53.3  94.67   95
# 3806  2017  ZWE    Zimbabwe         ZWE  14.236745   50.3  94.97   90
#
#             gdppc   lngdppc      hexp  balanced     lnpop  d_surv  d_imm  \
# 24    3945.594930  8.280355       NaN      True  2.731741     NaN    NaN
# 211   3902.774196  8.269443       NaN      True  2.764233    0.42  -18.0
# 400   3892.316925  8.266760  2.334435      True  2.797005    0.51   -7.0
# 589   3924.316196  8.274947  5.483824      True  2.830017    0.60   29.0
# 778   4314.540938  8.369746  4.072288      True  2.863310    0.69    0.0
# ...           ...       ...       ...       ...       ...     ...    ...
# 3042  2491.635140  7.820694  6.592539      True  2.591543    0.70   -4.0
# 3233  2506.490220  7.826639  8.670390      True  2.609090    0.57   -1.0
# 3424  2509.008140  7.827643  9.256197      True  2.625728    0.41   -6.0
# 3615  2489.097494  7.819675  9.413668      True  2.641226    0.37    9.0
# 3806  2568.410072  7.851042       NaN      True  2.655826    0.30   -5.0
#
#       d2_imm  d_lngdppc   d_lnpop     avgpop
# 24       NaN        NaN       NaN  21.792576
# 211      NaN  -0.010912  0.032492  21.792576
# 400     11.0  -0.002683  0.032772  21.792576
# 589     36.0   0.008188  0.033012  21.792576
# 778    -29.0   0.094799  0.033293  21.792576
# ...      ...        ...       ...        ...
# 3042    -9.0   0.001923  0.017776  12.622610
# 3233     3.0   0.005944  0.017547  12.622610
# 3424    -5.0   0.001004  0.016638  12.622610
# 3615    15.0  -0.007967  0.015498  12.622610
# 3806   -14.0   0.031367  0.014601  12.622610
#
# [3440 rows x 19 columns]

# %% [markdown]
# ## Fixed Effect

# %%
# %pip install linearmodels -q
from linearmodels import PanelOLS
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
data_balanced = data_balanced.assign(
    Year=lambda x: x["year"].astype("category")
).set_index(["c", "year"])

# %%
fe_lm = PanelOLS.from_formula("surv ~ imm + Year + EntityEffects", # Entity effects capture unobserved, constant differences between entities 
                                                                   # (e.g., countries) that do not change over time.
    data_balanced,
    weights=data_balanced["avgpop"],
).fit(cov_type="clustered", cluster_entity=True)

# %%
fe_lm.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   surv   R-squared:                        0.7172
# Estimator:                   PanelOLS   R-squared (Between):              0.4249
# No. Observations:                3440   R-squared (Within):               0.7172
# Date:                Fri, Sep 05 2025   R-squared (Overall):              0.4672
# Time:                        02:12:58   Log-likelihood                   -4053.2
# Cov. Estimator:             Clustered
#                                         F-statistic:                   1.668e+06
# Entities:                         172   P-value                           0.0000
# Avg Obs:                       20.000   Distribution:                 F(20,3248)
# Min Obs:                       20.000
# Max Obs:                       20.000   F-statistic (robust):          7.082e+08
#                                         P-value                           0.0000
# Time periods:                      20   Distribution:                 F(20,3248)
# Avg Obs:                       172.00
# Min Obs:                       172.00
# Max Obs:                       172.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# imm            0.0769     0.0099     7.7874     0.0000      0.0575      0.0963
# Year[1998]     87.775     0.7406     118.53     0.0000      86.323      89.227
# Year[1999]     87.946     0.7511     117.08     0.0000      86.473      89.419
# Year[2000]     88.145     0.7512     117.34     0.0000      86.672      89.618
# Year[2001]     88.349     0.7539     117.19     0.0000      86.871      89.827
# Year[2002]     88.627     0.7486     118.39     0.0000      87.159      90.094
# Year[2003]     88.769     0.7827     113.41     0.0000      87.234      90.304
# Year[2004]     88.860     0.8096     109.76     0.0000      87.273      90.448
# Year[2005]     89.029     0.8428     105.64     0.0000      87.377      90.682
# Year[2006]     89.092     0.8241     108.10     0.0000      87.476      90.707
# Year[2007]     89.274     0.8277     107.85     0.0000      87.651      90.897
# Year[2008]     89.348     0.8285     107.84     0.0000      87.723      90.972
# Year[2009]     89.416     0.8599     103.98     0.0000      87.730      91.102
# Year[2010]     89.519     0.8882     100.79     0.0000      87.778      91.261
# Year[2011]     89.662     0.9005     99.570     0.0000      87.897      91.428
# Year[2012]     89.835     0.8873     101.24     0.0000      88.095      91.575
# Year[2013]     90.001     0.8805     102.21     0.0000      88.274      91.727
# Year[2014]     90.143     0.8939     100.85     0.0000      88.391      91.896
# Year[2015]     90.238     0.9042     99.803     0.0000      88.465      92.011
# Year[2016]     90.358     0.9087     99.439     0.0000      88.576      92.139
# Year[2017]     90.456     0.8988     100.64     0.0000      88.694      92.218
# ==============================================================================
#
# F-test for Poolability: 113.18
# P-value: 0.0000
# Distribution: F(171,3248)
#
# Included effects: Entity
# """

# %%
# within R2
fe_lm.rsquared_within
# Out:
# 0.7172189726881084

# %%
fe_lm2 = PanelOLS.from_formula("surv ~ imm + lngdppc + lnpop + Year + EntityEffects",
    data_balanced,
    weights=data_balanced["avgpop"],
).fit(cov_type="clustered", cluster_entity=True)

# %%
fe_lm2.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   surv   R-squared:                        0.8484
# Estimator:                   PanelOLS   R-squared (Between):             -31.327
# No. Observations:                3440   R-squared (Within):               0.8484
# Date:                Fri, Sep 05 2025   R-squared (Overall):             -26.671
# Time:                        02:14:26   Log-likelihood                   -2981.3
# Cov. Estimator:             Clustered
#                                         F-statistic:                   2.826e+06
# Entities:                         172   P-value                           0.0000
# Avg Obs:                       20.000   Distribution:                 F(22,3246)
# Min Obs:                       20.000
# Max Obs:                       20.000   F-statistic (robust):          1.499e+09
#                                         P-value                           0.0000
# Time periods:                      20   Distribution:                 F(22,3246)
# Avg Obs:                       172.00
# Min Obs:                       172.00
# Max Obs:                       172.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# imm            0.0383     0.0109     3.5020     0.0005      0.0169      0.0598
# lngdppc        1.5927     0.3980     4.0013     0.0001      0.8122      2.3731
# lnpop          12.049     1.6432     7.3324     0.0000      8.8270      15.271
# Year[1998]     14.938     9.5350     1.5667     0.1173     -3.7571      33.633
# Year[1999]     14.923     9.5534     1.5620     0.1184     -3.8085      33.654
# Year[2000]     14.923     9.5758     1.5584     0.1192     -3.8527      33.698
# Year[2001]     14.944     9.5971     1.5571     0.1195     -3.8733      33.761
# Year[2002]     15.000     9.6240     1.5586     0.1192     -3.8696      33.870
# Year[2003]     14.972     9.6477     1.5519     0.1208     -3.9439      33.889
# Year[2004]     14.885     9.6714     1.5391     0.1239     -4.0776      33.848
# Year[2005]     14.862     9.6951     1.5330     0.1254     -4.1468      33.872
# Year[2006]     14.762     9.7068     1.5208     0.1284     -4.2699      33.794
# Year[2007]     14.716     9.7305     1.5124     0.1305     -4.3626      33.794
# Year[2008]     14.644     9.7487     1.5021     0.1332     -4.4704      33.758
# Year[2009]     14.603     9.7639     1.4956     0.1349     -4.5410      33.747
# Year[2010]     14.507     9.7862     1.4824     0.1383     -4.6806      33.695
# Year[2011]     14.473     9.8008     1.4767     0.1399     -4.7439      33.689
# Year[2012]     14.446     9.8184     1.4713     0.1413     -4.8053      33.697
# Year[2013]     14.408     9.8420     1.4639     0.1433     -4.8893      33.705
# Year[2014]     14.354     9.8681     1.4546     0.1459     -4.9940      33.703
# Year[2015]     14.280     9.8884     1.4441     0.1488     -5.1084      33.668
# Year[2016]     14.214     9.9102     1.4343     0.1516     -5.2169      33.645
# Year[2017]     14.134     9.9297     1.4234     0.1547     -5.3356      33.603
# ==============================================================================
#
# F-test for Poolability: 119.30
# P-value: 0.0000
# Distribution: F(171,3246)
#
# Included effects: Entity
# """

# %%
# within R2
fe_lm2.rsquared_within
# Out:
# 0.8483654071512511

# %%
# no weights, not in book
fe_lm2_nowts = PanelOLS.from_formula(
    "surv ~ imm + lngdppc + lnpop + Year + EntityEffects",
    data_balanced,
).fit(cov_type="clustered", cluster_entity=True)
fe_lm2_nowts
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   surv   R-squared:                        0.6151
# Estimator:                   PanelOLS   R-squared (Between):             -15.038
# No. Observations:                3440   R-squared (Within):               0.6151
# Date:                Fri, Sep 05 2025   R-squared (Overall):             -13.209
# Time:                        02:24:34   Log-likelihood                   -4664.9
# Cov. Estimator:             Clustered
#                                         F-statistic:                      235.79
# Entities:                         172   P-value                           0.0000
# Avg Obs:                       20.000   Distribution:                 F(22,3246)
# Min Obs:                       20.000
# Max Obs:                       20.000   F-statistic (robust):          2.756e+08
#                                         P-value                           0.0000
# Time periods:                      20   Distribution:                 F(22,3246)
# Avg Obs:                       172.00
# Min Obs:                       172.00
# Max Obs:                       172.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# imm            0.0381     0.0087     4.3633     0.0000      0.0210      0.0553
# lngdppc        2.5794     0.4447     5.8001     0.0000      1.7074      3.4513
# lnpop          7.7165     1.4742     5.2344     0.0000      4.8261      10.607
# Year[1998]     55.282     4.5223     12.224     0.0000      46.415      64.149
# Year[1999]     55.328     4.5274     12.221     0.0000      46.451      64.204
# Year[2000]     55.303     4.5415     12.177     0.0000      46.398      64.207
# Year[2001]     55.335     4.5518     12.157     0.0000      46.410      64.260
# Year[2002]     55.362     4.5614     12.137     0.0000      46.419      64.306
# Year[2003]     55.363     4.5743     12.103     0.0000      46.394      64.332
# Year[2004]     55.313     4.5873     12.058     0.0000      46.319      64.307
# Year[2005]     55.283     4.6019     12.013     0.0000      46.260      64.306
# Year[2006]     55.221     4.6220     11.948     0.0000      46.159      64.283
# Year[2007]     55.151     4.6451     11.873     0.0000      46.043      64.258
# Year[2008]     55.124     4.6587     11.832     0.0000      45.989      64.258
# Year[2009]     55.214     4.6601     11.848     0.0000      46.077      64.351
# Year[2010]     55.099     4.6780     11.778     0.0000      45.927      64.271
# Year[2011]     55.134     4.6916     11.752     0.0000      45.936      64.333
# Year[2012]     55.105     4.7067     11.708     0.0000      45.877      64.333
# Year[2013]     55.081     4.7231     11.662     0.0000      45.821      64.342
# Year[2014]     55.058     4.7409     11.613     0.0000      45.762      64.353
# Year[2015]     55.023     4.7580     11.564     0.0000      45.694      64.352
# Year[2016]     55.000     4.7727     11.524     0.0000      45.642      64.358
# Year[2017]     54.943     4.7886     11.474     0.0000      45.554      64.332
# ==============================================================================
#
# F-test for Poolability: 93.472
# P-value: 0.0000
# Distribution: F(171,3246)
#
# Included effects: Entity
# PanelEffectsResults, id: 0x7eba2bc019d0

# %%
# large difference in R2
print(fe_lm2_nowts.rsquared_within)
print(fe_lm2.rsquared_within)
# Out:
# 0.6151025994954715
# 0.8483654071512511

# %%
# CLUSTER SE VS BIASED SE

fe_lm3 = PanelOLS.from_formula(
    "surv ~ imm + lngdppc + lnpop + Year + EntityEffects",
    data_balanced,
    weights=data_balanced["avgpop"],
).fit(cov_type="robust")

# %%
fe_lm3
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   surv   R-squared:                        0.8484
# Estimator:                   PanelOLS   R-squared (Between):             -31.327
# No. Observations:                3440   R-squared (Within):               0.8484
# Date:                Fri, Sep 05 2025   R-squared (Overall):             -26.671
# Time:                        02:24:42   Log-likelihood                   -2981.3
# Cov. Estimator:                Robust
#                                         F-statistic:                   2.826e+06
# Entities:                         172   P-value                           0.0000
# Avg Obs:                       20.000   Distribution:                 F(22,3246)
# Min Obs:                       20.000
# Max Obs:                       20.000   F-statistic (robust):          3.164e+06
#                                         P-value                           0.0000
# Time periods:                      20   Distribution:                 F(22,3246)
# Avg Obs:                       172.00
# Min Obs:                       172.00
# Max Obs:                       172.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# imm            0.0383     0.0040     9.6752     0.0000      0.0306      0.0461
# lngdppc        1.5927     0.1225     13.000     0.0000      1.3524      1.8329
# lnpop          12.049     0.5156     23.368     0.0000      11.038      13.060
# Year[1998]     14.938     3.0364     4.9196     0.0000      8.9846      20.891
# Year[1999]     14.923     3.0357     4.9158     0.0000      8.9707      20.875
# Year[2000]     14.923     3.0397     4.9091     0.0000      8.9625      20.883
# Year[2001]     14.944     3.0460     4.9060     0.0000      8.9715      20.916
# Year[2002]     15.000     3.0537     4.9121     0.0000      9.0127      20.988
# Year[2003]     14.972     3.0601     4.8928     0.0000      8.9725      20.972
# Year[2004]     14.885     3.0675     4.8525     0.0000      8.8707      20.899
# Year[2005]     14.862     3.0736     4.8355     0.0000      8.8360      20.889
# Year[2006]     14.762     3.0800     4.7929     0.0000      8.7233      20.801
# Year[2007]     14.716     3.0893     4.7635     0.0000      8.6587      20.773
# Year[2008]     14.644     3.0950     4.7315     0.0000      8.5755      20.712
# Year[2009]     14.603     3.0996     4.7113     0.0000      8.5257      20.680
# Year[2010]     14.507     3.1083     4.6672     0.0000      8.4127      20.602
# Year[2011]     14.473     3.1142     4.6473     0.0000      8.3665      20.579
# Year[2012]     14.446     3.1204     4.6294     0.0000      8.3274      20.564
# Year[2013]     14.408     3.1280     4.6062     0.0000      8.2750      20.541
# Year[2014]     14.354     3.1357     4.5777     0.0000      8.2063      20.503
# Year[2015]     14.280     3.1408     4.5465     0.0000      8.1215      20.438
# Year[2016]     14.214     3.1458     4.5185     0.0000      8.0461      20.382
# Year[2017]     14.134     3.1491     4.4881     0.0000      7.9591      20.308
# ==============================================================================
#
# F-test for Poolability: 119.30
# P-value: 0.0000
# Distribution: F(171,3246)
#
# Included effects: Entity
# PanelEffectsResults, id: 0x7eba16a810d0

# %% [markdown]
# ## First Difference

# %%
data_balanced = data_balanced.reset_index()
data_balanced["year"] = data_balanced["year"].astype("category")

# %%
# Basic fd
model = smf.wls("d_surv ~ d_imm", data_balanced, weights=data_balanced["pop"])
fd_lm = model.fit(
    cov_type="cluster",
    cov_kwds={"groups": data_balanced.loc[model.data.row_labels, "c"]},
)
fd_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 d_surv   R-squared:                       0.013
# Model:                            WLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     12.53
# Date:                Mon, 03 Oct 2022   Prob (F-statistic):           0.000515
# Time:                        13:38:48   Log-Likelihood:                -2984.5
# No. Observations:                3268   AIC:                             5973.
# Df Residuals:                    3266   BIC:                             5985.
# Df Model:                           1
# Covariance Type:              cluster
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1885      0.024      7.702      0.000       0.141       0.236
# d_imm          0.0086      0.002      3.540      0.000       0.004       0.013
# ==============================================================================
# Omnibus:                     1714.815   Durbin-Watson:                   1.730
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         15867835.538
# Skew:                           0.518   Prob(JB):                         0.00
# Kurtosis:                     344.367   Cond. No.                         3.44
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
# FD, 5 lags
model = smf.wls(
    "d_surv ~ d_imm.shift(0) + d_imm.shift(1) + d_imm.shift(2) + d_imm.shift(3) + d_imm.shift(4) + d_imm.shift(5)",
    data_balanced,
    weights=data_balanced["pop"],
)
fd_lm_5 = model.fit(
    cov_type="cluster",
    cov_kwds={"groups": data_balanced.loc[model.data.row_labels, "c"]},
)
fd_lm_5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 d_surv   R-squared:                       0.078
# Model:                            WLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     8.170
# Date:                Mon, 03 Oct 2022   Prob (F-statistic):           8.90e-08
# Time:                        13:38:48   Log-Likelihood:                -2235.1
# No. Observations:                2408   AIC:                             4484.
# Df Residuals:                    2401   BIC:                             4525.
# Df Model:                           6
# Covariance Type:              cluster
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          0.1361      0.018      7.532      0.000       0.101       0.172
# d_imm.shift(0)     0.0099      0.002      5.310      0.000       0.006       0.014
# d_imm.shift(1)     0.0100      0.002      5.833      0.000       0.007       0.013
# d_imm.shift(2)     0.0111      0.002      4.747      0.000       0.007       0.016
# d_imm.shift(3)     0.0092      0.002      4.672      0.000       0.005       0.013
# d_imm.shift(4)     0.0069      0.002      3.768      0.000       0.003       0.010
# d_imm.shift(5)     0.0059      0.002      3.421      0.001       0.003       0.009
# ==============================================================================
# Omnibus:                     1246.475   Durbin-Watson:                   2.149
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         16509408.542
# Skew:                           0.341   Prob(JB):                         0.00
# Kurtosis:                     408.642   Cond. No.                         4.69
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
# FD, 5 lags, cumul

model = smf.wls(
    "d_surv ~ d_imm.shift(5) + d2_imm.shift(0) + d2_imm.shift(1) + d2_imm.shift(2) + d2_imm.shift(3) + d2_imm.shift(4)",
    data_balanced,
    weights=data_balanced["pop"],
)
fd_lm_5_cumul = model.fit(
    cov_type="cluster",
    cov_kwds={"groups": data_balanced.loc[model.data.row_labels, "c"]},
)
fd_lm_5_cumul.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 d_surv   R-squared:                       0.078
# Model:                            WLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     8.170
# Date:                Mon, 03 Oct 2022   Prob (F-statistic):           8.90e-08
# Time:                        13:38:48   Log-Likelihood:                -2235.1
# No. Observations:                2408   AIC:                             4484.
# Df Residuals:                    2401   BIC:                             4525.
# Df Model:                           6
# Covariance Type:              cluster
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.1361      0.018      7.532      0.000       0.101       0.172
# d_imm.shift(5)      0.0529      0.010      5.496      0.000       0.034       0.072
# d2_imm.shift(0)     0.0099      0.002      5.310      0.000       0.006       0.014
# d2_imm.shift(1)     0.0199      0.003      5.878      0.000       0.013       0.026
# d2_imm.shift(2)     0.0309      0.005      5.912      0.000       0.021       0.041
# d2_imm.shift(3)     0.0401      0.007      6.010      0.000       0.027       0.053
# d2_imm.shift(4)     0.0470      0.008      5.813      0.000       0.031       0.063
# ==============================================================================
# Omnibus:                     1246.475   Durbin-Watson:                   2.149
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         16509408.542
# Skew:                           0.341   Prob(JB):                         0.00
# Kurtosis:                     408.642   Cond. No.                         8.89
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %%
# FD, 5 lags, cumul, lead

fd_lm_5_cumul_lead_formula = "d_surv ~ d_imm.shift(5) + d2_imm.shift(0) + \
d2_imm.shift(1) + d2_imm.shift(2) + d2_imm.shift(3) + \
d2_imm.shift(4) + d_imm.shift(-1) + d_imm.shift(-2) + d_imm.shift(-3)"

model = smf.wls(
    fd_lm_5_cumul_lead_formula,
    data_balanced,
    weights=data_balanced["pop"],
)

fd_lm_5_cumul_lead = model.fit(
    cov_type="cluster",
    cov_kwds={"groups": data_balanced.loc[model.data.row_labels, "c"]},
)

# %%
fd_lm_5_cumul_lead.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 d_surv   R-squared:                       0.093
# Model:                            WLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     12.30
# Date:                Mon, 03 Oct 2022   Prob (F-statistic):           6.48e-15
# Time:                        13:38:48   Log-Likelihood:                -1937.3
# No. Observations:                1892   AIC:                             3895.
# Df Residuals:                    1882   BIC:                             3950.
# Df Model:                           9
# Covariance Type:              cluster
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.1245      0.018      6.960      0.000       0.089       0.160
# d_imm.shift(5)      0.0543      0.008      6.839      0.000       0.039       0.070
# d2_imm.shift(0)     0.0109      0.002      7.213      0.000       0.008       0.014
# d2_imm.shift(1)     0.0207      0.003      7.985      0.000       0.016       0.026
# d2_imm.shift(2)     0.0317      0.005      6.709      0.000       0.022       0.041
# d2_imm.shift(3)     0.0402      0.006      6.977      0.000       0.029       0.051
# d2_imm.shift(4)     0.0471      0.007      6.943      0.000       0.034       0.060
# d_imm.shift(-1)     0.0084      0.002      5.312      0.000       0.005       0.012
# d_imm.shift(-2)     0.0074      0.002      3.583      0.000       0.003       0.011
# d_imm.shift(-3)     0.0050      0.003      1.920      0.055      -0.000       0.010
# ==============================================================================
# Omnibus:                      975.559   Durbin-Watson:                   2.296
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         10903619.758
# Skew:                           0.329   Prob(JB):                         0.00
# Kurtosis:                     374.903   Cond. No.                         9.30
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# """

# %% [markdown]
# ___

# %% [markdown]
# ### AGGREG TREND, CONFOUNDERS, CTRY TRENDS

# %%
# FD, 5 lags, cumul, aggreg trend

fd_lm_5_cumul_trend_formula = "d_surv ~ d_imm.shift(5) + d2_imm.shift(0) + d2_imm.shift(1) + \
d2_imm.shift(2) + d2_imm.shift(3) + d2_imm.shift(4) + year"

model = smf.wls(
    fd_lm_5_cumul_trend_formula,
    data_balanced,
    weights=data_balanced["pop"],
)

fd_lm_5_cumul_trend = model.fit(
    cov_type="cluster",
    cov_kwds={"groups": data_balanced.loc[model.data.row_labels, "c"]},
)

fd_lm_5_cumul_trend.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 d_surv   R-squared:                       0.088
# Model:                            WLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     39.66
# Date:                Mon, 03 Oct 2022   Prob (F-statistic):           1.17e-53
# Time:                        13:38:49   Log-Likelihood:                -2221.0
# No. Observations:                2408   AIC:                             4482.
# Df Residuals:                    2388   BIC:                             4598.
# Df Model:                          19
# Covariance Type:              cluster
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.1280      0.017      7.342      0.000       0.094       0.162
# year[T.1999]    -2.764e-17    6.5e-18     -4.251      0.000   -4.04e-17   -1.49e-17
# year[T.2000]     1.003e-19   8.48e-18      0.012      0.991   -1.65e-17    1.67e-17
# year[T.2001]    -8.467e-19   1.41e-17     -0.060      0.952   -2.85e-17    2.68e-17
# year[T.2002]     2.276e-18   1.08e-17      0.211      0.833   -1.89e-17    2.34e-17
# year[T.2003]      1.71e-17   9.57e-18      1.787      0.074   -1.65e-18    3.59e-17
# year[T.2004]        0.0458      0.031      1.465      0.143      -0.015       0.107
# year[T.2005]        0.0814      0.026      3.175      0.002       0.031       0.132
# year[T.2006]        0.0304      0.008      3.901      0.000       0.015       0.046
# year[T.2007]        0.0261      0.007      3.814      0.000       0.013       0.039
# year[T.2008]       -0.0137      0.019     -0.735      0.463      -0.050       0.023
# year[T.2009]        0.0085      0.023      0.363      0.717      -0.037       0.054
# year[T.2010]       -0.0316      0.022     -1.437      0.151      -0.075       0.012
# year[T.2011]        0.0056      0.025      0.222      0.824      -0.044       0.055
# year[T.2012]       -0.0051      0.006     -0.876      0.381      -0.017       0.006
# year[T.2013]       -0.0044      0.006     -0.780      0.436      -0.015       0.007
# year[T.2014]        0.0001      0.006      0.019      0.985      -0.012       0.013
# year[T.2015]     8.965e-06      0.009      0.001      0.999      -0.018       0.018
# year[T.2016]       -0.0042      0.011     -0.391      0.696      -0.025       0.017
# year[T.2017]       -0.0108      0.010     -1.046      0.296      -0.031       0.009
# d_imm.shift(5)      0.0525      0.010      5.051      0.000       0.032       0.073
# d2_imm.shift(0)     0.0091      0.002      4.868      0.000       0.005       0.013
# d2_imm.shift(1)     0.0183      0.004      5.067      0.000       0.011       0.025
# d2_imm.shift(2)     0.0294      0.005      5.425      0.000       0.019       0.040
# d2_imm.shift(3)     0.0387      0.007      5.340      0.000       0.024       0.053
# d2_imm.shift(4)     0.0462      0.009      5.350      0.000       0.029       0.063
# ==============================================================================
# Omnibus:                     1257.052   Durbin-Watson:                   2.160
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         17077360.415
# Skew:                           0.373   Prob(JB):                         0.00
# Kurtosis:                     415.560   Cond. No.                     1.45e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.58e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# *FD, 5 lags, cumul, aggreg trend, confounders

fd_lm_5_cumul_trend_c_formula = (
    "d_surv ~ d_imm.shift(5) + "
    + " + ".join(["d2_imm.shift({i})".format(i=i) for i in range(0, 5)])
    + " + "
    + " + ".join(["d_lngdppc.shift({i})".format(i=i) for i in range(0, 6)])
    + " + "
    + " + ".join(["d_lnpop.shift({i})".format(i=i) for i in range(0, 6)])
    + " + year"
)

# %%
model = smf.wls(
    fd_lm_5_cumul_trend_c_formula,
    data_balanced,
    weights=data_balanced["pop"],
)

fd_lm_5_cumul_trend_c = model.fit(
    cov_type="cluster",
    cov_kwds={"groups": data_balanced.loc[model.data.row_labels, "c"]},
)

fd_lm_5_cumul_trend_c.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 d_surv   R-squared:                       0.212
# Model:                            WLS   Adj. R-squared:                  0.201
# Method:                 Least Squares   F-statistic:                     65.51
# Date:                Mon, 03 Oct 2022   Prob (F-statistic):           9.04e-80
# Time:                        13:38:49   Log-Likelihood:                -2046.1
# No. Observations:                2408   AIC:                             4156.
# Df Residuals:                    2376   BIC:                             4341.
# Df Model:                          31
# Covariance Type:              cluster
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             -0
-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# * check: cumulative coeffs on the confounders

# %%
hypotheses = (
    " + ".join(["d_lngdppc.shift({i})".format(i=i) for i in range(0, 6)]) + " = 0"
)
f_test = fd_lm_5_cumul_trend_c.f_test(hypotheses)

print(f_test)
# Out:
# <F test: F=12.07461529483102, p=0.0006477451801072691, df_denom=171, df_num=1>

# %%
hypotheses = (
    " + ".join(["d_lnpop.shift({i})".format(i=i) for i in range(0, 6)]) + " = 0"
)
f_test = fd_lm_5_cumul_trend_c.f_test(hypotheses)

print(f_test)
# Out:
# <F test: F=54.11448822337828, p=7.540868463691176e-12, df_denom=171, df_num=1>

# %%
# * check: it's not the number of obsrevations

# %%
data_balanced_filtered = data_balanced.dropna(subset=["d_lngdppc"])

# %%
model = smf.wls(
    fd_lm_5_cumul_trend_formula,
    data_balanced_filtered,
    weights=data_balanced_filtered["pop"],
)

fd_lm_5_cumul_trend2 = model.fit(
    cov_type="cluster",
    cov_kwds={"groups": data_balanced_filtered.loc[model.data.row_labels, "c"]},
)

fd_lm_5_cumul_trend2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 d_surv   R-squared:                       0.088
# Model:                            WLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     39.66
# Date:                Mon, 03 Oct 2022   Prob (F-statistic):           1.17e-53
# Time:                        13:38:49   Log-Likelihood:                -2221.0
# No. Observations:                2408   AIC:                             4482.
# Df Residuals:                    2388   BIC:                             4598.
# Df Model:                          19
# Covariance Type:              cluster
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.1280      0.017      7.342      0.000       0.094       0.162
# year[T.1999]    -2.764e-17    6.5e-18     -4.251      0.000   -4.04e-17   -1.49e-17
# year[T.2000]     1.003e-19   8.48e-18      0.012      0.991   -1.65e-17    1.67e-17
# year[T.2001]    -8.467e-19   1.41e-17     -0.060      0.952   -2.85e-17    2.68e-17
# year[T.2002]     2.276e-18   1.08e-17      0.211      0.833   -1.89e-17    2.34e-17
# year[T.2003]      1.71e-17   9.57e-18      1.787      0.074   -1.65e-18    3.59e-17
# year[T.2004]        0.0458      0.031      1.465      0.143      -0.015       0.107
# year[T.2005]        0.0814      0.026      3.175      0.002       0.031       0.132
# year[T.2006]        0.0304      0.008      3.901      0.000       0.015       0.046
# year[T.2007]        0.0261      0.007      3.814      0.000       0.013       0.039
# year[T.2008]       -0.0137      0.019     -0.735      0.463      -0.050       0.023
# year[T.2009]        0.0085      0.023      0.363      0.717      -0.037       0.054
# year[T.2010]       -0.0316      0.022     -1.437      0.151      -0.075       0.012
# year[T.2011]        0.0056      0.025      0.222      0.824      -0.044       0.055
# year[T.2012]       -0.0051      0.006     -0.876      0.381      -0.017       0.006
# year[T.2013]       -0.0044      0.006     -0.780      0.436      -0.015       0.007
# year[T.2014]        0.0001      0.006      0.019      0.985      -0.012       0.013
# year[T.2015]     8.965e-06      0.009      0.001      0.999      -0.018       0.018
# year[T.2016]       -0.0042      0.011     -0.391      0.696      -0.025       0.017
# year[T.2017]       -0.0108      0.010     -1.046      0.296      -0.031       0.009
# d_imm.shift(5)      0.0525      0.010      5.051      0.000       0.032       0.073
# d2_imm.shift(0)     0.0091      0.002      4.868      0.000       0.005       0.013
# d2_imm.shift(1)     0.0183      0.004      5.067      0.000       0.011       0.025
# d2_imm.shift(2)     0.0294      0.005      5.425      0.000       0.019       0.040
# d2_imm.shift(3)     0.0387      0.007      5.340      0.000       0.024       0.053
# d2_imm.shift(4)     0.0462      0.009      5.350      0.000       0.029       0.063
# ==============================================================================
# Omnibus:                     1257.052   Durbin-Watson:                   2.160
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         17077360.415
# Skew:                           0.373   Prob(JB):                         0.00
# Kurtosis:                     415.560   Cond. No.                     1.45e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors are robust to cluster correlation (cluster)
# [2] The smallest eigenvalue is 1.58e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
fd_lm_5_cumul_trend_c_country_formula = (
    "d_surv ~ d_imm.shift(5) + "
    + " + ".join(["d2_imm.shift({i})".format(i=i) for i in range(0, 5)])
    + " + "
    + " + ".join(["d_lngdppc.shift({i})".format(i=i) for i in range(0, 6)])
    + " + "
    + " + ".join(["d_lnpop.shift({i})".format(i=i) for i in range(0, 6)])
    + " + year + c"
)

model = smf.wls(
    fd_lm_5_cumul_trend_c_country_formula,
    data_balanced,
    weights=data_balanced["pop"],
)

fd_lm_5_cumul_trend_c_country = model.fit(
    cov_type="cluster",
    cov_kwds={"groups": data_balanced.loc[model.data.row_labels, "c"]},
)

fd_lm_5_cumul_trend_c_country.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                 d_surv   R-squared:                       0.331
# Model:                            WLS   Adj. R-squared:                  0.270
# Method:                 Least Squares   F-statistic:                 5.007e+04
# Date:                Mon, 03 Oct 2022   Prob (F-statistic):          4.20e-322
# Time:                        13:38:50   Log-Likelihood:                -1847.7
# No. Observations:                2408   AIC:                             4101.
# Df Residuals:                    2205   BIC:                             5276.
# Df Model:                         202
# Covariance Type:              cluster
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              0.6620      0.065     10.262      0.000       0.536       0.788
# year[T.1999]        -4.85e-15    5.1e-15     -0.950      0.342   -1.49e-14    5.16e-15
# year[T.2000]       -3.455e-13   4.15e-14     -8.324      0.000   -4.27e-13   -2.64e-13
# year[T.2001]       -8.772e-13   7.73e-14    -11.341      0.000   -1.03e-12   -7.26e-13
# year[T.2002]       -4.208e-13   2.72e-14    -15.448      0.000   -4.74e-13   -3.67e-13
# year[T.2003]        -9.23e-14    3.3e-14     -2.795      0.005   -1.57e-13   -2.76e-14
# year[T.2004]           0.0767      0.031      2.509      0.012       0.017       0.137
# year[T.2005]           0.1188      0.024      4.853      0.000       0.071       0.167
# year[T.2006]           0.0735      0.012      6.386      0.000       0.051       0.096
# year[T.2007]           0.0709      0.011      6.189      0.000       0.048       0.093
# year[T.2008]           0.0588      0.022      2.617      0.009       0.015       0.103
# year[T.2009]           0.0828      0.024      3.427      0.001       0.035       0.130
# year[T.2010]           0.0126      0.037      0.344      0.731      -0.059       0.085
# year[T.2011]           0.0672      0.029      2.353      0.019       0.011       0.123
# year[T.2012]           0.0374      0.006      6.485      0.000       0.026       0.049
# year[T.2013]           0.0260      0.007      3.868      0.000       0.013       0.039
# year[T.2014]           0.0224      0.006      3.557      0.000       0.010       0.035
# year[T.2015]           0.0156      0.005      2.854      0.004       0.005       0.026
# year[T.2016]           0.0047      0.006      0.791      0.429      -0.007       0.016
# year[T.2017]          -0.0054      0.007     -0.784      0.433      -0.019       0.008
